# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 729

# %%
# Import the requests library.
import requests

# Import the API key.
from config2 import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f7284bc393f4def48b506e6cdc4ae316

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | hasaki
# Processing Record 3 of Set 1 | airai
# Processing Record 4 of Set 1 | lebu
# Processing Record 5 of Set 1 | lincoln
# Processing Record 6 of Set 1 | new norfolk
# Processing Record 7 of Set 1 | port elizabeth
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | college
# Processing Record 10 of Set 1 | bethel
# Processing Record 11 of Set 1 | bluff
# Processing Record 12 of Set 1 | bengkulu
# Processing Record 13 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 1 | egvekinot
# Processing Record 15 of Set 1 | avarua
# Processing Record 16 of Set 1 | butaritari
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | sitka
# Processing Record 19 of Set 1 | camacupa
# Processing Record 20 of Set 1 | pangnirtung
# Processing Record 21 of Set 1 | plerin
# Processing Record 22 of Set 1 | upernavik
# Processing Record 23 of Set 1 | nayoro
# Processing Record 24 of Set 1 | anadyr
# Processing Record 25 of Set 1 | klaksvik
# Processing Record 26 of Set 1 | georgetown
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | esperance
# Processing Record 29 of Set 1 | talnakh
# Processing Record 30 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 1 | hobart
# Processing Record 32 of Set 1 | torbay
# Processing Record 33 of Set 1 | sibolga
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | nome
# Processing Record 37 of Set 1 | bud
# Processing Record 38 of Set 1 | cherskiy
# Processing Record 39 of Set 1 | ilulissat
# Processing Record 40 of Set 1 | dikson
# Processing Record 41 of Set 1 | haukipudas
# Processing Record 42 of Set 1 | hobyo
# Processing Record 43 of Set 1 | saint-pierre
# Processing Record 44 of Set 1 | satipo
# Processing Record 45 of Set 1 | yellowknife
# Processing Record 46 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 1 | port keats
# Processing Record 48 of Set 1 | trinidad
# Processing Record 49 of Set 1 | wagar
# Processing Record 50 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 2 | saint-francois
# Processing Record 2 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 2 | moyale
# Processing Record 4 of Set 2 | arraial do cabo
# Processing Record 5 of Set 2 | east london
# Processing Record 6 of Set 2 | khatanga
# Processing Record 7 of Set 2 | hamilton
# Processing Record 8 of Set 2 | flinders
# Processing Record 9 of Set 2 | saskylakh
# Processing Record 10 of Set 2 | albanel
# Processing Record 11 of Set 2 | jamestown
# Processing Record 12 of Set 2 | boqueirao
# Processing Record 13 of Set 2 | atuona
# Processing Record 14 of Set 2 | jumla
# Processing Record 15 of Set 2 | severomuysk
# Processing Record 16 of Set 2 | salalah
# Processing Record 17 of Set 2 | manama
# Processing Record 18 of Set 2 | luderitz
# Processing Record 19 of Set 2 | iqaluit
# Processing Record 20 of Set 2 | nanortalik
# Processing Record 21 of Set 2 | clyde river
# Processing Record 22 of Set 2 | lebanon
# Processing Record 23 of Set 2 | iseyin
# Processing Record 24 of Set 2 | nikolskoye
# Processing Record 25 of Set 2 | darnah
# Processing Record 26 of Set 2 | ferrol
# Processing Record 27 of Set 2 | north bend
# Processing Record 28 of Set 2 | port alfred
# Processing Record 29 of Set 2 | mataura
# Processing Record 30 of Set 2 | qaanaaq
# Processing Record 31 of Set 2 | avera
# Processing Record 32 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 2 | port moresby
# Processing Record 34 of Set 2 | pemangkat
# Processing Record 35 of Set 2 | bredasdorp
# Processing Record 36 of Set 2 | the valley
# Processing Record 37 of Set 2 | pevek
# Processing Record 38 of Set 2 | vaini
# Processing Record 39 of Set 2 | vila franca do campo
# Processing Record 40 of Set 2 | ayna
# Processing Record 41 of Set 2 | kapaa
# Processing Record 42 of Set 2 | souillac
# Processing Record 43 of Set 2 | barrow
# Processing Record 44 of Set 2 | armizonskoye
# Processing Record 45 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 2 | cumaribo
# City not found. Skipping...
# Processing Record 47 of Set 2 | ushibuka
# Processing Record 48 of Set 2 | ajdabiya
# Processing Record 49 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 2 | beyneu
# Processing Record 1 of Set 3 | kishtwar
# Processing Record 2 of Set 3 | faenza
# Processing Record 3 of Set 3 | rikitea
# Processing Record 4 of Set 3 | half moon bay
# Processing Record 5 of Set 3 | kodiak
# Processing Record 6 of Set 3 | uaua
# Processing Record 7 of Set 3 | namibe
# Processing Record 8 of Set 3 | mazagao
# Processing Record 9 of Set 3 | lata
# Processing Record 10 of Set 3 | fairview
# Processing Record 11 of Set 3 | vanimo
# Processing Record 12 of Set 3 | mozarlandia
# Processing Record 13 of Set 3 | vaitape
# Processing Record 14 of Set 3 | mahebourg
# Processing Record 15 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 16 of Set 3 | mushie
# Processing Record 17 of Set 3 | chokurdakh
# Processing Record 18 of Set 3 | thompson
# Processing Record 19 of Set 3 | faanui
# Processing Record 20 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 3 | carnarvon
# Processing Record 22 of Set 3 | cabedelo
# Processing Record 23 of Set 3 | vytegra
# Processing Record 24 of Set 3 | rawson
# Processing Record 25 of Set 3 | fortuna
# Processing Record 26 of Set 3 | morwell
# Processing Record 27 of Set 3 | dingle
# Processing Record 28 of Set 3 | port-de-paix
# City not found. Skipping...
# Processing Record 29 of Set 3 | tessalit
# Processing Record 30 of Set 3 | faya
# Processing Record 31 of Set 3 | saint-philippe
# Processing Record 32 of Set 3 | antofagasta
# Processing Record 33 of Set 3 | severo-kurilsk
# Processing Record 34 of Set 3 | puerto ayora
# Processing Record 35 of Set 3 | bafoulabe
# Processing Record 36 of Set 3 | ponta do sol
# Processing Record 37 of Set 3 | vermillion
# Processing Record 38 of Set 3 | kijang
# Processing Record 39 of Set 3 | mitsamiouli
# Processing Record 40 of Set 3 | dunedin
# Processing Record 41 of Set 3 | brae
# Processing Record 42 of Set 3 | banda aceh
# Processing Record 43 of Set 3 | coahuayana
# Processing Record 44 of Set 3 | baoro
# Processing Record 45 of Set 3 | napasar
# Processing Record 46 of Set 3 | raudeberg
# Processing Record 47 of Set 3 | khandyga
# Processing Record 48 of Set 3 | kruisfontein
# Processing Record 49 of Set 3 | beloha
# Processing Record 50 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 4 | alice springs
# Processing Record 2 of Set 4 | tuktoyaktuk
# Processing Record 3 of Set 4 | los llanos de aridane
# Processing Record 4 of Set 4 | saint george
# Processing Record 5 of Set 4 | nanchang
# Processing Record 6 of Set 4 | canico
# Processing Record 7 of Set 4 | mutoko
# Processing Record 8 of Set 4 | bam
# Processing Record 9 of Set 4 | kaitangata
# Processing Record 10 of Set 4 | arlit
# Processing Record 11 of Set 4 | mahon
# Processing Record 12 of Set 4 | morgan city
# Processing Record 13 of Set 4 | zaysan
# Processing Record 14 of Set 4 | ribeira grande
# Processing Record 15 of Set 4 | samarai
# Processing Record 16 of Set 4 | chor
# Processing Record 17 of Set 4 | parakou
# Processing Record 18 of Set 4 | dire
# Processing Record 19 of Set 4 | moree
# Processing Record 20 of Set 4 | hami
# Processing Record 21 of Set 4 | bambanglipuro
# Processing Record 22 of Set 4 | illapel
# Processing Record 23 of Set 4 | marawi
# Processing Record 24 of Set 4 | castro
# Processing Record 25 of Set 4 | ust-uda
# Processing Record 26 of Set 4 | berbera
# Processing Record 27 of Set 4 | rincon de la victoria
# Processing Record 28 of Set 4 | muros
# Processing Record 29 of Set 4 | leningradskiy
# Processing Record 30 of Set 4 | vardo
# Processing Record 31 of Set 4 | acapulco
# Processing Record 32 of Set 4 | lufilufi
# Processing Record 33 of Set 4 | pangkalanbuun
# Processing Record 34 of Set 4 | magdalena
# Processing Record 35 of Set 4 | ostrovnoy
# Processing Record 36 of Set 4 | cidreira
# Processing Record 37 of Set 4 | zhanatas
# City not found. Skipping...
# Processing Record 38 of Set 4 | verkhoyansk
# Processing Record 39 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 4 | plouzane
# Processing Record 41 of Set 4 | provideniya
# Processing Record 42 of Set 4 | san alberto
# Processing Record 43 of Set 4 | bilibino
# Processing Record 44 of Set 4 | marsa matruh
# Processing Record 45 of Set 4 | quatre cocos
# Processing Record 46 of Set 4 | ballina
# Processing Record 47 of Set 4 | vanavara
# Processing Record 48 of Set 4 | eureka
# Processing Record 49 of Set 4 | muncar
# Processing Record 50 of Set 4 | toftir
# City not found. Skipping...
# Processing Record 1 of Set 5 | lagoa nova
# Processing Record 2 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 5 | kloulklubed
# Processing Record 4 of Set 5 | lagoa
# Processing Record 5 of Set 5 | cabo san lucas
# Processing Record 6 of Set 5 | naze
# Processing Record 7 of Set 5 | tasiilaq
# Processing Record 8 of Set 5 | fare
# Processing Record 9 of Set 5 | port macquarie
# Processing Record 10 of Set 5 | montevideo
# Processing Record 11 of Set 5 | ondorhaan
# City not found. Skipping...
# Processing Record 12 of Set 5 | aksarayskiy
# Processing Record 13 of Set 5 | sechura
# Processing Record 14 of Set 5 | la ronge
# Processing Record 15 of Set 5 | tiksi
# Processing Record 16 of Set 5 | salym
# Processing Record 17 of Set 5 | tahe
# Processing Record 18 of Set 5 | pemberton
# Processing Record 19 of Set 5 | ungheni
# Processing Record 20 of Set 5 | muroto
# Processing Record 21 of Set 5 | san quintin
# Processing Record 22 of Set 5 | fairbanks
# Processing Record 23 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 5 | boali
# Processing Record 25 of Set 5 | kurumkan
# Processing Record 26 of Set 5 | viedma
# Processing Record 27 of Set 5 | srednekolymsk
# Processing Record 28 of Set 5 | huangpi
# Processing Record 29 of Set 5 | mlyniv
# Processing Record 30 of Set 5 | craig
# Processing Record 31 of Set 5 | grand gaube
# Processing Record 32 of Set 5 | port lincoln
# Processing Record 33 of Set 5 | bambous virieux
# Processing Record 34 of Set 5 | ugoofaaru
# Processing Record 35 of Set 5 | nurmijarvi
# Processing Record 36 of Set 5 | payo
# Processing Record 37 of Set 5 | comodoro rivadavia
# Processing Record 38 of Set 5 | vada
# Processing Record 39 of Set 5 | isangel
# Processing Record 40 of Set 5 | jabiru
# City not found. Skipping...
# Processing Record 41 of Set 5 | zhigansk
# Processing Record 42 of Set 5 | mogadishu
# Processing Record 43 of Set 5 | martapura
# Processing Record 44 of Set 5 | labuhan
# Processing Record 45 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 46 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 5 | sohag
# Processing Record 48 of Set 5 | kuchinarai
# Processing Record 49 of Set 5 | barra do garcas
# Processing Record 50 of Set 5 | boras
# Processing Record 1 of Set 6 | kupang
# Processing Record 2 of Set 6 | yulara
# Processing Record 3 of Set 6 | victoria
# Processing Record 4 of Set 6 | shingu
# Processing Record 5 of Set 6 | svetlogorsk
# Processing Record 6 of Set 6 | conceicao da barra
# Processing Record 7 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 6 | hermanus
# Processing Record 9 of Set 6 | monster
# Processing Record 10 of Set 6 | dali
# Processing Record 11 of Set 6 | nipawin
# Processing Record 12 of Set 6 | la primavera
# Processing Record 13 of Set 6 | namatanai
# Processing Record 14 of Set 6 | guerrero negro
# Processing Record 15 of Set 6 | joshimath
# Processing Record 16 of Set 6 | north platte
# Processing Record 17 of Set 6 | grand-santi
# Processing Record 18 of Set 6 | sorland
# Processing Record 19 of Set 6 | lichuan
# Processing Record 20 of Set 6 | shache
# Processing Record 21 of Set 6 | solenzo
# Processing Record 22 of Set 6 | masuda
# Processing Record 23 of Set 6 | paterno
# Processing Record 24 of Set 6 | mangan
# Processing Record 25 of Set 6 | estepona
# Processing Record 26 of Set 6 | hambantota
# Processing Record 27 of Set 6 | sterlibashevo
# Processing Record 28 of Set 6 | kahului
# Processing Record 29 of Set 6 | amos
# Processing Record 30 of Set 6 | cabatuan
# Processing Record 31 of Set 6 | kandrian
# Processing Record 32 of Set 6 | ulladulla
# Processing Record 33 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 34 of Set 6 | pio ix
# Processing Record 35 of Set 6 | geraldton
# Processing Record 36 of Set 6 | san patricio
# Processing Record 37 of Set 6 | bathsheba
# Processing Record 38 of Set 6 | tevriz
# Processing Record 39 of Set 6 | odienne
# Processing Record 40 of Set 6 | fort nelson
# Processing Record 41 of Set 6 | trelew
# Processing Record 42 of Set 6 | longyearbyen
# Processing Record 43 of Set 6 | koslan
# Processing Record 44 of Set 6 | steinbach
# Processing Record 45 of Set 6 | lakselv
# Processing Record 46 of Set 6 | osakarovka
# Processing Record 47 of Set 6 | taoudenni
# Processing Record 48 of Set 6 | kalmunai
# Processing Record 49 of Set 6 | fez
# Processing Record 50 of Set 6 | lakatoro
# Processing Record 1 of Set 7 | abilene
# Processing Record 2 of Set 7 | bull savanna
# Processing Record 3 of Set 7 | zhitikara
# City not found. Skipping...
# Processing Record 4 of Set 7 | parrsboro
# Processing Record 5 of Set 7 | ola
# Processing Record 6 of Set 7 | boyuibe
# Processing Record 7 of Set 7 | magaria
# Processing Record 8 of Set 7 | taltal
# Processing Record 9 of Set 7 | great yarmouth
# Processing Record 10 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 7 | pingliang
# Processing Record 12 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 13 of Set 7 | chaihe
# Processing Record 14 of Set 7 | genhe
# Processing Record 15 of Set 7 | inuvik
# Processing Record 16 of Set 7 | zhangjiakou
# Processing Record 17 of Set 7 | itupiranga
# Processing Record 18 of Set 7 | newport
# Processing Record 19 of Set 7 | maltahohe
# Processing Record 20 of Set 7 | sebinkarahisar
# Processing Record 21 of Set 7 | bay roberts
# Processing Record 22 of Set 7 | ancud
# Processing Record 23 of Set 7 | la macarena
# Processing Record 24 of Set 7 | riyadh
# Processing Record 25 of Set 7 | zurrieq
# Processing Record 26 of Set 7 | lompoc
# Processing Record 27 of Set 7 | torrevieja
# Processing Record 28 of Set 7 | mehamn
# Processing Record 29 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 30 of Set 7 | muli
# Processing Record 31 of Set 7 | santa maria da vitoria
# Processing Record 32 of Set 7 | skjervoy
# Processing Record 33 of Set 7 | san carlos de bariloche
# Processing Record 34 of Set 7 | kokubu
# Processing Record 35 of Set 7 | port hardy
# Processing Record 36 of Set 7 | chumikan
# Processing Record 37 of Set 7 | buncrana
# Processing Record 38 of Set 7 | banjarmasin
# Processing Record 39 of Set 7 | manono
# Processing Record 40 of Set 7 | broken hill
# Processing Record 41 of Set 7 | peru
# Processing Record 42 of Set 7 | waikuku
# Processing Record 43 of Set 7 | mayo
# Processing Record 44 of Set 7 | novomichurinsk
# Processing Record 45 of Set 7 | mambajao
# Processing Record 46 of Set 7 | ambilobe
# Processing Record 47 of Set 7 | yar-sale
# Processing Record 48 of Set 7 | blackwater
# Processing Record 49 of Set 7 | ishimbay
# Processing Record 50 of Set 7 | tula
# Processing Record 1 of Set 8 | estevan
# Processing Record 2 of Set 8 | tottori
# Processing Record 3 of Set 8 | goryachegorsk
# Processing Record 4 of Set 8 | laguna
# Processing Record 5 of Set 8 | storforshei
# Processing Record 6 of Set 8 | chuy
# Processing Record 7 of Set 8 | coquimbo
# Processing Record 8 of Set 8 | roma
# Processing Record 9 of Set 8 | kamenka
# Processing Record 10 of Set 8 | nouadhibou
# Processing Record 11 of Set 8 | kasongo-lunda
# Processing Record 12 of Set 8 | mar del plata
# Processing Record 13 of Set 8 | ixtapa
# Processing Record 14 of Set 8 | mount isa
# Processing Record 15 of Set 8 | hithadhoo
# Processing Record 16 of Set 8 | matara
# Processing Record 17 of Set 8 | mwinilunga
# Processing Record 18 of Set 8 | znamenskoye
# Processing Record 19 of Set 8 | waddan
# Processing Record 20 of Set 8 | aripuana
# Processing Record 21 of Set 8 | ajaccio
# Processing Record 22 of Set 8 | middelburg
# Processing Record 23 of Set 8 | maiduguri
# Processing Record 24 of Set 8 | denia
# Processing Record 25 of Set 8 | porbandar
# Processing Record 26 of Set 8 | vacaville
# Processing Record 27 of Set 8 | coihaique
# Processing Record 28 of Set 8 | havelock
# Processing Record 29 of Set 8 | inta
# Processing Record 30 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 8 | betare oya
# Processing Record 32 of Set 8 | barwadih
# Processing Record 33 of Set 8 | podbelsk
# City not found. Skipping...
# Processing Record 34 of Set 8 | mayahi
# Processing Record 35 of Set 8 | san julian
# Processing Record 36 of Set 8 | alekseyevsk
# Processing Record 37 of Set 8 | kirkwall
# Processing Record 38 of Set 8 | finschhafen
# Processing Record 39 of Set 8 | colwyn bay
# Processing Record 40 of Set 8 | kvarkeno
# Processing Record 41 of Set 8 | meadow lake
# Processing Record 42 of Set 8 | mozhga
# Processing Record 43 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 44 of Set 8 | grindavik
# Processing Record 45 of Set 8 | gamba
# Processing Record 46 of Set 8 | ukiah
# Processing Record 47 of Set 8 | natal
# Processing Record 48 of Set 8 | biltine
# Processing Record 49 of Set 8 | shimoda
# Processing Record 50 of Set 8 | husavik
# Processing Record 1 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 2 of Set 9 | samandag
# Processing Record 3 of Set 9 | englewood
# Processing Record 4 of Set 9 | itarema
# Processing Record 5 of Set 9 | sinnamary
# Processing Record 6 of Set 9 | birin
# Processing Record 7 of Set 9 | dekernes
# Processing Record 8 of Set 9 | oldebroek
# Processing Record 9 of Set 9 | petatlan
# Processing Record 10 of Set 9 | oksfjord
# Processing Record 11 of Set 9 | cazaje
# City not found. Skipping...
# Processing Record 12 of Set 9 | puerto del rosario
# Processing Record 13 of Set 9 | vao
# Processing Record 14 of Set 9 | bonga
# Processing Record 15 of Set 9 | vilnius
# Processing Record 16 of Set 9 | tura
# Processing Record 17 of Set 9 | burica
# City not found. Skipping...
# Processing Record 18 of Set 9 | bosaso
# Processing Record 19 of Set 9 | huarmey
# Processing Record 20 of Set 9 | mercedes
# Processing Record 21 of Set 9 | roald
# Processing Record 22 of Set 9 | izberbash
# Processing Record 23 of Set 9 | tommot
# Processing Record 24 of Set 9 | sur
# Processing Record 25 of Set 9 | imbituba
# Processing Record 26 of Set 9 | codrington
# Processing Record 27 of Set 9 | jasper
# Processing Record 28 of Set 9 | bafra
# Processing Record 29 of Set 9 | betamcherla
# Processing Record 30 of Set 9 | nelson bay
# Processing Record 31 of Set 9 | kikwit
# Processing Record 32 of Set 9 | micomeseng
# Processing Record 33 of Set 9 | kieta
# Processing Record 34 of Set 9 | thessalon
# Processing Record 35 of Set 9 | aklavik
# Processing Record 36 of Set 9 | yazman
# Processing Record 37 of Set 9 | hirara
# Processing Record 38 of Set 9 | zanjan
# Processing Record 39 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 40 of Set 9 | nurota
# Processing Record 41 of Set 9 | saquena
# Processing Record 42 of Set 9 | muisne
# Processing Record 43 of Set 9 | lavrentiya
# Processing Record 44 of Set 9 | port-gentil
# Processing Record 45 of Set 9 | neuquen
# Processing Record 46 of Set 9 | dawei
# Processing Record 47 of Set 9 | pustoshka
# Processing Record 48 of Set 9 | micheweni
# Processing Record 49 of Set 9 | at-bashi
# Processing Record 50 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 1 of Set 10 | iwaki
# Processing Record 2 of Set 10 | aviles
# Processing Record 3 of Set 10 | chernihiv
# Processing Record 4 of Set 10 | nicoya
# Processing Record 5 of Set 10 | kensington
# Processing Record 6 of Set 10 | bonavista
# Processing Record 7 of Set 10 | orocue
# Processing Record 8 of Set 10 | kharp
# Processing Record 9 of Set 10 | west plains
# Processing Record 10 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 10 | dongsheng
# Processing Record 12 of Set 10 | san ignacio
# Processing Record 13 of Set 10 | khani
# Processing Record 14 of Set 10 | amahai
# Processing Record 15 of Set 10 | angoche
# Processing Record 16 of Set 10 | budogoshch
# Processing Record 17 of Set 10 | jacksonville
# Processing Record 18 of Set 10 | channel-port aux basques
# Processing Record 19 of Set 10 | kulhudhuffushi
# Processing Record 20 of Set 10 | qesarya
# Processing Record 21 of Set 10 | kodinsk
# Processing Record 22 of Set 10 | caetite
# Processing Record 23 of Set 10 | goderich
# Processing Record 24 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 25 of Set 10 | saldanha
# Processing Record 26 of Set 10 | sistranda
# Processing Record 27 of Set 10 | san luis
# Processing Record 28 of Set 10 | hangu
# Processing Record 29 of Set 10 | pisco
# Processing Record 30 of Set 10 | shangrao
# Processing Record 31 of Set 10 | paamiut
# Processing Record 32 of Set 10 | chiautla
# Processing Record 33 of Set 10 | sauda
# Processing Record 34 of Set 10 | galle
# Processing Record 35 of Set 10 | saint anthony
# Processing Record 36 of Set 10 | las palmas
# Processing Record 37 of Set 10 | haines junction
# Processing Record 38 of Set 10 | charagua
# Processing Record 39 of Set 10 | polunochnoye
# Processing Record 40 of Set 10 | mari-turek
# Processing Record 41 of Set 10 | stepnoye
# Processing Record 42 of Set 10 | bondoukou
# Processing Record 43 of Set 10 | cairns
# Processing Record 44 of Set 10 | owatonna
# Processing Record 45 of Set 10 | springbok
# Processing Record 46 of Set 10 | ternate
# Processing Record 47 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 10 | lasa
# Processing Record 49 of Set 10 | cukai
# Processing Record 50 of Set 10 | hihya
# Processing Record 1 of Set 11 | lambarene
# Processing Record 2 of Set 11 | constitucion
# Processing Record 3 of Set 11 | madhupur
# Processing Record 4 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 5 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 6 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 11 | ust-ishim
# Processing Record 8 of Set 11 | tocoa
# Processing Record 9 of Set 11 | beringovskiy
# Processing Record 10 of Set 11 | ozark
# Processing Record 11 of Set 11 | izumo
# Processing Record 12 of Set 11 | felanitx
# Processing Record 13 of Set 11 | srisailam
# Processing Record 14 of Set 11 | santiago del estero
# Processing Record 15 of Set 11 | awjilah
# Processing Record 16 of Set 11 | karwar
# Processing Record 17 of Set 11 | deputatskiy
# Processing Record 18 of Set 11 | norfolk
# Processing Record 19 of Set 11 | weinan
# Processing Record 20 of Set 11 | northam
# Processing Record 21 of Set 11 | rantepao
# Processing Record 22 of Set 11 | talcahuano
# Processing Record 23 of Set 11 | puerto narino
# Processing Record 24 of Set 11 | khairpur nathan shah
# Processing Record 25 of Set 11 | tupik
# Processing Record 26 of Set 11 | beian
# Processing Record 27 of Set 11 | broome
# Processing Record 28 of Set 11 | portoferraio
# Processing Record 29 of Set 11 | ciudad bolivar
# Processing Record 30 of Set 11 | baykit
# Processing Record 31 of Set 11 | muslyumovo
# Processing Record 32 of Set 11 | yaring
# Processing Record 33 of Set 11 | richards bay
# Processing Record 34 of Set 11 | villa carlos paz
# Processing Record 35 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 36 of Set 11 | kirovsk
# Processing Record 37 of Set 11 | ewa beach
# Processing Record 38 of Set 11 | benguela
# Processing Record 39 of Set 11 | jalu
# Processing Record 40 of Set 11 | nortelandia
# Processing Record 41 of Set 11 | hay river
# Processing Record 42 of Set 11 | puri
# Processing Record 43 of Set 11 | dudinka
# Processing Record 44 of Set 11 | whitianga
# Processing Record 45 of Set 11 | belaya gora
# Processing Record 46 of Set 11 | deep river
# Processing Record 47 of Set 11 | sembe
# Processing Record 48 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 11 | agva
# City not found. Skipping...
# Processing Record 50 of Set 11 | knysna
# Processing Record 1 of Set 12 | envira
# Processing Record 2 of Set 12 | pandua
# Processing Record 3 of Set 12 | san cristobal
# Processing Record 4 of Set 12 | imeni vorovskogo
# Processing Record 5 of Set 12 | soledad
# Processing Record 6 of Set 12 | victor harbor
# Processing Record 7 of Set 12 | bara
# Processing Record 8 of Set 12 | medea
# Processing Record 9 of Set 12 | santiago
# Processing Record 10 of Set 12 | jieshi
# Processing Record 11 of Set 12 | llanes
# Processing Record 12 of Set 12 | yenagoa
# Processing Record 13 of Set 12 | kyshtovka
# Processing Record 14 of Set 12 | lodja
# Processing Record 15 of Set 12 | sinazongwe
# Processing Record 16 of Set 12 | ous
# Processing Record 17 of Set 12 | madison
# Processing Record 18 of Set 12 | aranos
# Processing Record 19 of Set 12 | esil
# Processing Record 20 of Set 12 | tiznit
# Processing Record 21 of Set 12 | waingapu
# Processing Record 22 of Set 12 | rocha
# Processing Record 23 of Set 12 | valparaiso
# Processing Record 24 of Set 12 | ceres
# Processing Record 25 of Set 12 | guilin
# Processing Record 26 of Set 12 | lukulu
# Processing Record 27 of Set 12 | khorramshahr
# Processing Record 28 of Set 12 | capaci
# Processing Record 29 of Set 12 | leninskoye
# Processing Record 30 of Set 12 | houma
# Processing Record 31 of Set 12 | boende
# Processing Record 32 of Set 12 | nefteyugansk
# Processing Record 33 of Set 12 | okandja
# City not found. Skipping...
# Processing Record 34 of Set 12 | shahr-e kord
# Processing Record 35 of Set 12 | kleck
# City not found. Skipping...
# Processing Record 36 of Set 12 | biskamzha
# Processing Record 37 of Set 12 | katsuura
# Processing Record 38 of Set 12 | kaseda
# Processing Record 39 of Set 12 | mamlyutka
# Processing Record 40 of Set 12 | cap malheureux
# Processing Record 41 of Set 12 | isiro
# Processing Record 42 of Set 12 | san francisco del mar
# Processing Record 43 of Set 12 | dickson
# Processing Record 44 of Set 12 | nichinan
# Processing Record 45 of Set 12 | aberdeen
# Processing Record 46 of Set 12 | ambon
# Processing Record 47 of Set 12 | kapuskasing
# Processing Record 48 of Set 12 | batemans bay
# Processing Record 49 of Set 12 | sobolevo
# Processing Record 50 of Set 12 | balkhash
# Processing Record 1 of Set 13 | prince rupert
# Processing Record 2 of Set 13 | touros
# Processing Record 3 of Set 13 | rafai
# Processing Record 4 of Set 13 | muhos
# Processing Record 5 of Set 13 | yelnya
# Processing Record 6 of Set 13 | caravelas
# Processing Record 7 of Set 13 | kununurra
# Processing Record 8 of Set 13 | abu zabad
# Processing Record 9 of Set 13 | komsomolskiy
# Processing Record 10 of Set 13 | vestmanna
# Processing Record 11 of Set 13 | sedelnikovo
# City not found. Skipping...
# Processing Record 12 of Set 13 | sioux lookout
# Processing Record 13 of Set 13 | pskov
# Processing Record 14 of Set 13 | san mateo del mar
# Processing Record 15 of Set 13 | rock sound
# Processing Record 16 of Set 13 | argelia
# Processing Record 17 of Set 13 | aksu
# Processing Record 18 of Set 13 | santa fe
# Processing Record 19 of Set 13 | aquidauana
# Processing Record 20 of Set 13 | mbuji-mayi
# Processing Record 21 of Set 13 | la rioja
# Processing Record 22 of Set 13 | cocorit
# Processing Record 23 of Set 13 | fortuna foothills
# Processing Record 24 of Set 13 | aloleng
# Processing Record 25 of Set 13 | tiruvottiyur
# City not found. Skipping...
# Processing Record 26 of Set 13 | bushehr
# Processing Record 27 of Set 13 | luancheng
# Processing Record 28 of Set 13 | zaltan
# Processing Record 29 of Set 13 | wattegama
# Processing Record 30 of Set 13 | regina
# Processing Record 31 of Set 13 | chabahar
# Processing Record 32 of Set 13 | pasighat
# Processing Record 33 of Set 13 | burshtyn
# Processing Record 34 of Set 13 | koungou
# Processing Record 35 of Set 13 | mount gambier
# Processing Record 36 of Set 13 | marzuq
# Processing Record 37 of Set 13 | tateyama
# Processing Record 38 of Set 13 | camacha
# Processing Record 39 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 40 of Set 13 | batala
# Processing Record 41 of Set 13 | la baule-escoublac
# Processing Record 42 of Set 13 | chilca
# Processing Record 43 of Set 13 | port blair
# Processing Record 44 of Set 13 | semme
# Processing Record 45 of Set 13 | cuamba
# Processing Record 46 of Set 13 | vite
# Processing Record 47 of Set 13 | durango
# Processing Record 48 of Set 13 | inverell
# Processing Record 49 of Set 13 | ayan
# Processing Record 50 of Set 13 | santa rosa
# Processing Record 1 of Set 14 | alcudia
# Processing Record 2 of Set 14 | bandarbeyla
# Processing Record 3 of Set 14 | rio gallegos
# Processing Record 4 of Set 14 | moussoro
# Processing Record 5 of Set 14 | uzhur
# Processing Record 6 of Set 14 | puerto el triunfo
# Processing Record 7 of Set 14 | mazyr
# Processing Record 8 of Set 14 | cayenne
# Processing Record 9 of Set 14 | caluquembe
# Processing Record 10 of Set 14 | bonnyville
# Processing Record 11 of Set 14 | calamar
# Processing Record 12 of Set 14 | sompeta
# Processing Record 13 of Set 14 | zemio
# Processing Record 14 of Set 14 | kavaratti
# Processing Record 15 of Set 14 | hagere hiywet
# Processing Record 16 of Set 14 | isla vista
# Processing Record 17 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 14 | ihosy
# Processing Record 19 of Set 14 | bilgi
# Processing Record 20 of Set 14 | mayor pablo lagerenza
# Processing Record 21 of Set 14 | buala
# Processing Record 22 of Set 14 | conceicao do araguaia
# Processing Record 23 of Set 14 | solnechnyy
# Processing Record 24 of Set 14 | slave lake
# Processing Record 25 of Set 14 | seddon
# Processing Record 26 of Set 14 | cockburn town
# Processing Record 27 of Set 14 | ankazoabo
# Processing Record 28 of Set 14 | usak
# Processing Record 29 of Set 14 | jaru
# Processing Record 30 of Set 14 | san pedro
# Processing Record 31 of Set 14 | arcachon
# Processing Record 32 of Set 14 | capitao poco
# Processing Record 33 of Set 14 | kiruna
# Processing Record 34 of Set 14 | russell
# Processing Record 35 of Set 14 | male
# Processing Record 36 of Set 14 | kongolo
# Processing Record 37 of Set 14 | kitui
# Processing Record 38 of Set 14 | gagarin
# Processing Record 39 of Set 14 | mehran
# Processing Record 40 of Set 14 | sidi ali
# Processing Record 41 of Set 14 | banmo
# City not found. Skipping...
# Processing Record 42 of Set 14 | kaeo
# Processing Record 43 of Set 14 | seoul
# Processing Record 44 of Set 14 | taksimo
# Processing Record 45 of Set 14 | veinticinco de mayo
# Processing Record 46 of Set 14 | kelso
# Processing Record 47 of Set 14 | ouango
# Processing Record 48 of Set 14 | zelenogorskiy
# Processing Record 49 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 14 | angamali
# Processing Record 1 of Set 15 | kyren
# Processing Record 2 of Set 15 | matoury
# Processing Record 3 of Set 15 | sinop
# Processing Record 4 of Set 15 | semnan
# Processing Record 5 of Set 15 | ialibu
# Processing Record 6 of Set 15 | terra roxa
# Processing Record 7 of Set 15 | estelle
# Processing Record 8 of Set 15 | padang
# Processing Record 9 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 10 of Set 15 | ambulu
# Processing Record 11 of Set 15 | gilgit
# Processing Record 12 of Set 15 | byron bay
# Processing Record 13 of Set 15 | ranong
# Processing Record 14 of Set 15 | palmer
# Processing Record 15 of Set 15 | vila velha
# Processing Record 16 of Set 15 | hualmay
# Processing Record 17 of Set 15 | saravan
# Processing Record 18 of Set 15 | bonthe
# Processing Record 19 of Set 15 | alofi
# Processing Record 20 of Set 15 | morogoro
# Processing Record 21 of Set 15 | manavalakurichi
# Processing Record 22 of Set 15 | jilib
# Processing Record 23 of Set 15 | lubango
# Processing Record 24 of Set 15 | turukhansk
# Processing Record 25 of Set 15 | nagato
# Processing Record 26 of Set 15 | hecun
# Processing Record 27 of Set 15 | ardistan
# City not found. Skipping...
# Processing Record 28 of Set 15 | aksarka
# Processing Record 29 of Set 15 | gurskoye
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Cape Town -33.9258   18.4232     69.01        82          20
# 1          Hasaki  35.7333  140.8333     50.00        43          20
# 2           Airai  -8.9266  125.4092     62.47       100         100
# 3            Lebu -37.6167  -73.6500     57.83        90           2
# 4         Lincoln  40.8000  -96.6670     45.00        80           1
# 5     New Norfolk -42.7826  147.0587     73.00        64          20
# 6  Port Elizabeth -33.9180   25.5701     68.00        88           0
# 7         Ushuaia -54.8000  -68.3000     51.80        62          75
# 8         College  64.8569 -147.8028     -5.80        71          90
# 9          Bethel  41.3712  -73.4140     30.20        64          90
#
#    Wind Speed Country Current Description
# 0       11.50      ZA          few clouds
# 1       17.27      JP          few clouds
# 2        3.29      TL     overcast clouds
# 3       13.04      CL           clear sky
# 4        7.43      US           clear sky
# 5        6.91      AU          few clouds
# 6        9.22      ZA           clear sky
# 7        6.91      AR       broken clouds
# 8        3.44      US          light snow
# 9        8.05      US     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Cape Town      ZA -33.9258   18.4232     69.01        82          20
# 1          Hasaki      JP  35.7333  140.8333     50.00        43          20
# 2           Airai      TL  -8.9266  125.4092     62.47       100         100
# 3            Lebu      CL -37.6167  -73.6500     57.83        90           2
# 4         Lincoln      US  40.8000  -96.6670     45.00        80           1
# 5     New Norfolk      AU -42.7826  147.0587     73.00        64          20
# 6  Port Elizabeth      ZA -33.9180   25.5701     68.00        88           0
# 7         Ushuaia      AR -54.8000  -68.3000     51.80        62          75
# 8         College      US  64.8569 -147.8028     -5.80        71          90
# 9          Bethel      US  41.3712  -73.4140     30.20        64          90
#
#    Wind Speed Current Description
# 0       11.50          few clouds
# 1       17.27          few clouds
# 2        3.29     overcast clouds
# 3       13.04           clear sky
# 4        7.43           clear sky
# 5        6.91          few clouds
# 6        9.22           clear sky
# 7        6.91       broken clouds
# 8        3.44          light snow
# 9        8.05     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
